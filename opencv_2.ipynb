# %% [markdown]
# <a href="https://colab.research.google.com/github/Ganesh9100/opencv/blob/master/opencv_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np 
import cv2

# %%
image=cv2.imread("/content/finf.jpeg")
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)


plt.figure(figsize=(15,5))
plt.axis("off")
plt.imshow(image)

# %%
image=image.reshape((image.shape[0]*image.shape[1]),3)

# %%
image.shape
# Out:
# (921600, 3)

# %%
clt=KMeans(n_clusters=2)
clt.fit(image)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
clt.labels_ # returns the cluster no for each data point , eg : for 1st data point it is assigned to 2nd cluster
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int32)

# %%
numLabels = np.arange(0, len(np.unique(clt.labels_)) + 1)
(hist, _) = np.histogram(clt.labels_, bins = numLabels)

# %%
hist = hist.astype("float")
hist /= hist.sum()

# %%
#a=[2,3,3,4,3,2,5,1]
#np.unique(a)
centroids=clt.cluster_centers_

# %%
bar = np.zeros((50, 300, 3), dtype = "uint8")
startX = 0

# %%
for (percent, color) in zip(hist, centroids):
		# plot the relative percentage of each cluster
		endX = startX + (percent * 300)
		cv2.rectangle(bar, (int(startX), 0), (int(endX), 50),color.astype("uint8").tolist(), -1)
		startX = endX

# %%
#hist =centroid_histogram(clt)
#bar =plot_colors(hist, clt.cluster_centers_)
# show our color bart
plt.figure()
plt.axis("off")
plt.imshow(bar)
plt.show()
